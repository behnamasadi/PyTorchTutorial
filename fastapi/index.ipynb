# %% [markdown]
# ## 1. FastAPI
#
# ### 1.1. Install
#
# ```bash
# pip install fastapi "uvicorn[standard]"
# ```
#
# ### 1.2. A simple app (`main.py`)
#
# ```python
# from fastapi import FastAPI, Query
#
# app = FastAPI()
#
#
# @app.get("/add")
# def add_numbers(
#     num1: int = Query(..., description="First number"),
#     num2: int = Query(..., description="Second number"),
# ):
#     result = num1 + num2
#     return {"num1": num1, "num2": num2, "sum": result}
# ```
#
# ### 1.3. Run it
#
# ```bash
# uvicorn main:app --reload
# ```
#
# ### 1.4. Test it
#
# ```bash
# curl "http://127.0.0.1:8000/add?num1=3&num2=7"
# ```
#
# ```json
# {"num1": 3, "num2": 7, "sum": 10}
# ```
#
# ### 1.5. Swagger docs
#
# FastAPI auto-generates interactive API docs at `http://127.0.0.1:8000/docs`.

# %% [markdown]
# ## 2. Query, Path, Body, Header, Cookie
#
# FastAPI uses **special classes** (`Query`, `Path`, `Body`, `Header`, `Cookie`, …) to tell the framework **where to extract values from an HTTP request**.
# The syntax is always the same:
#
# ```python
# param_name: type = Source(default_value, extra_config...)
# ```
#
# Where **Source** can be `Query`, `Path`, `Body`, etc.
#
# ---

# %% [markdown]
# ### 2.1 Query
# Extracts data from the **query string** (the `?foo=bar` part of the URL).
#
#
# ```python
# num1: int = Query(..., description="First value")
# ```
#
# ---
#
#
# ```bash
# num1: int = Query(..., description="First number")
# ^      ^      ^
# |      |      |
# |      |      +-- Query object with metadata
# |      +-- Type hint (for validation & docs)
# +-- Parameter name (appears in URL)
# ```
#
#
# ---
#
# #### 2.1.1 **`num1: int`**
#
# This is a **type hint**.
#
# * It says "`num1` must be an integer".
# * FastAPI uses this to **validate and convert** the incoming query parameter.
#
# ---
#
# #### 2.1.2 **`= Query(...)`**
#
# `Query` is a helper function from FastAPI that lets you configure query parameters.
#
# * `Query(...)`
#
#   * The `...` (ellipsis) means **required**.
#   * If you don’t pass `num1`, FastAPI will throw a validation error (422 Unprocessable Entity).
# * You can also do:
#
#   ```python
#   num1: int = Query(None)   # optional, defaults to None
#   num2: int = Query(10)  # optional, defaults to 10
#   ```
#
# So the ellipsis (`...`) = “no default value → must be provided”.
#
# ---
#
# #### 2.1.3. **`description="First value"`**
#
# This adds documentation to the parameter in the **OpenAPI schema**.
#
# * When you open `/docs`, the Swagger UI will show “First value” next to the field.
#
# ---

# %% [markdown]
# ###  2.2.`Path`
#
# Extracts data from the **path parameters** (the `/items/{id}` part of the URL).
#
# Example:
#
# ```python
# from fastapi import Path
#
# @app.get("/items/{item_id}")
# def read_item(item_id: int = Path(..., description="The ID of the item", ge=1)):
#     return {"item_id": item_id}
# ```
#
#
# Now call:
#
# ```bash
# curl "http://127.0.0.1:8000/items/123"
# ```
#
#
#
# * `GET /items/123` → `{"item_id": 123}`
# * `...` → required
# * `ge=1` → validation (must be ≥ 1)
#
# ⚡ Difference vs `Query`:
#
# * `Query` pulls from URL query string.
# * `Path` pulls from the URL path itself.
#
# ---
#
# ## 2.3. Body
#
# Extracts data from the **request body** (mainly used with `POST`, `PUT`, `PATCH`).
# Usually combined with **Pydantic models** for validation.
#
# Example:
#
# ```python
# from fastapi import Body
# from pydantic import BaseModel
#
# class Item(BaseModel):
#     name: str
#     price: float
#
# @app.post("/items")
# def create_item(item: Item = Body(..., description="Item details")):
#     return {"name": item.name, "price": item.price}
# ```
#
# Request:
#
# ```bash
# curl -X POST "http://127.0.0.1:8000/items" \
#      -H "Content-Type: application/json" \
#      -d '{"name":"Laptop","price":999.99}'
# ```
#
# Response:
#
# ```json
# {"name":"Laptop","price":999.99}
# ```
#
# ⚡ Difference vs `Query`/`Path`:
#
# * `Query`/`Path` handle small values (strings, ints, filters).
# * `Body` handles structured JSON payloads.
#
# ---
#
# **Quick Analogy**
#
# Imagine a **restaurant order**:
#
# * `Path` = the **table number** → fixed in the path (`/tables/7/order`).
# * `Query` = the **extra instructions** you shout (`?extra_cheese=yes`).
# * `Body` = the **actual order sheet** you hand to the waiter (JSON payload).
#
# ---
#
# ✅ TL;DR:
#
# * **Query** → `/endpoint?foo=bar` (filters, search, options).
# * **Path** → `/endpoint/{id}` (identifiers, resource locators).
# * **Body** → request body, usually JSON (creation, updates, structured data).
#
# ---

# %% [markdown]
# ## 3. Semantics of Endpoint
#
# * **`GET`** → Used for *reading* data. Shouldn’t change the server state. Parameters go in the query string (`/get?foo1=...`).
# * **`POST`** → Used for *creating or submitting* data. The body carries the payload (usually JSON). Most common when you’re sending data that may be large, sensitive, or complex.
# * **`PUT`** → Used for *replacing/updating* an existing resource (idempotent: same call twice = same result).
#
# In your case:
#
# * If you just want a simple calculator (no state saved on server), `GET` is fine.
# * If you expect **bigger/structured input** (e.g., arrays, JSON objects), then `POST` is more common.
# * `PUT` would not be typical here, because you’re not updating a resource — just computing something.
#
# Here’s the same example as `POST` with JSON input:
#
# ```python
# from fastapi import FastAPI
# from pydantic import BaseModel
#
# app = FastAPI()
#
# class Numbers(BaseModel):
#     foo1: int
#     foo2: int
#
# @app.post("/add")
# def add_numbers(data: Numbers):
#     result = data.foo1 + data.foo2
#     return {"foo1": data.foo1, "foo2": data.foo2, "sum": result}
# ```
#
# Call with `curl`:
#
# ```bash
# curl -X POST "http://127.0.0.1:8000/add" \
#      -H "Content-Type: application/json" \
#      -d '{"foo1": 5, "foo2": 8}'
# ```
#
# Response:
#
# ```json
# {"foo1":5,"foo2":8,"sum":13}
# ```
#
# ---
#
# So:
#
# * **Testing, quick params** → `GET`
# * **Real-world API, structured input** → `POST`

# %% [markdown]
# ## 4. Gunicorn + Uvicorn (reference)
#
# > **Note:** Our Docker setup uses Uvicorn directly (no Gunicorn) to keep things simple.
# > This section is a reference for when you need multi-process production deployments.
#
#
# ### 4.1. What are they?
# - **Gunicorn** "Green Unicorn": a production-grade Python WSGI HTTP server. Handles process management, worker scaling, and request handling.
# - **Uvicorn**: an ASGI web server for Python (async).
#
# ASGI vs WSGI:
# - **WSGI** is synchronous — processes requests one at a time per worker.
# - **ASGI** is asynchronous — can handle multiple requests concurrently per worker.
#
# FastAPI is ASGI, so it needs Uvicorn. Gunicorn can manage multiple Uvicorn workers.
#
# ### 4.2. Running with Gunicorn
#
# ```bash
# gunicorn -k uvicorn.workers.UvicornWorker -w 2 -b 0.0.0.0:8000 main:app
# ```
#
# | Flag | Meaning |
# |------|---------|
# | `-k uvicorn.workers.UvicornWorker` | Use Uvicorn as the async engine inside Gunicorn |
# | `-w 2` | Spawn 2 worker processes (rule of thumb: `2 * CPU cores + 1`) |
# | `-b 0.0.0.0:8000` | Bind to all interfaces on port 8000 |
# | `main:app` | `main.py` file, `app` variable |
#
# ### 4.3. Running with Uvicorn only (what we use)
#
# ```bash
# uvicorn main:app --host 0.0.0.0 --port 8000
# ```
#
# This is simpler and works well for:
# - Development
# - Single-container deployments behind a reverse proxy (Nginx)
# - Exercises like this one
#
# | Feature          | Uvicorn only | Gunicorn + Uvicorn |
# | ---------------- | ------------ | ------------------ |
# | Multi-process    | No           | Yes                |
# | Complexity       | Low          | Higher             |
# | Production-ready | Behind proxy | Standalone         |
#
# ### 4.4. Health check
#
# ```python
# @app.get("/healthz")
# def health():
#     return {"status": "ok"}
# ```

# %% [markdown]
# ## 5. Task Queue (Redis + RQ)
#
# ### 5.1. Why a task queue?
#
# Some operations take too long for a normal HTTP request (generating reports, processing images, ML inference, sending emails). Instead of making the caller wait, the API:
#
# 1. **Accepts the request immediately** — returns a `job_id`
# 2. **Queues the work** — puts it in Redis
# 3. **A worker picks it up** — processes it in the background
# 4. **The caller checks back later** — `GET /reports/{job_id}`
#
# The caller has no idea there's a queue. They just see a normal REST API:
#
# ```
# POST /reports/               -> {"job_id": "abc-123", "status": "queued"}
# GET  /reports/abc-123        -> {"status": "started"}
# GET  /reports/abc-123        -> {"status": "finished", "result": {...}}
# ```
#
# Under the hood:
#
# ```
# [POST /reports/] -> [FastAPI] -> enqueue -> [Redis] -> dequeue -> [Worker runs generate_report()]
#                        |                                              |
#                        returns job_id immediately                     writes result to Redis
# ```
#
# ### 5.2. Install
#
# ```bash
# pip install fastapi "uvicorn[standard]" redis rq
# ```
#
# ### 5.3. Redis + RQ — two things working together
#
# | | **Redis** | **RQ** |
# |---|---|---|
# | **What** | In-memory database (server) | Python library |
# | **Role** | Storage engine | Job queue logic |
# | **pip package** | `redis` (Python client) | `rq` |
# | **Docker** | `redis:7-alpine` (server) | not needed (runs inside your app) |
# | **Analogy** | The filing cabinet | The secretary who manages the cabinet |
#
# You always need both. RQ stores everything (jobs, status, results) inside Redis — it has no storage of its own.
#
# ### 5.4. `tasks.py` — define the work
#
# ```python
# from time import sleep
# import random
#
# def generate_report(report_type: str):
#     """Simulate a report that takes real time to generate."""
#     durations = {
#         "sales": 8,
#         "inventory": 5,
#         "analytics": 12,
#     }
#     duration = durations.get(report_type, 6)
#     sleep(duration)
#     return {
#         "report_type": report_type,
#         "rows": random.randint(100, 5000),
#         "status": "complete",
#     }
# ```
#
# This function runs **inside the worker process**, not inside FastAPI. The worker picks it off the queue and executes it.
#
# ### 5.5. Full `main.py` — the API with queue
#
# Now we expand `main.py` from section 1 with Redis/RQ and two new endpoints:
#
# ```python
# from enum import Enum
#
# from fastapi import FastAPI, Path, Query
# from redis import Redis
# from rq import Queue
# from rq.job import Job
# from tasks import generate_report
#
#
# class ReportType(str, Enum):
#     sales = "sales"
#     inventory = "inventory"
#     analytics = "analytics"
#
#
# app = FastAPI()
# redis_conn = Redis(host="redis", port=6379)
# queue = Queue(connection=redis_conn)
#
#
# @app.get("/add")
# def add_numbers(
#     num1: int = Query(..., description="First number"),
#     num2: int = Query(..., description="Second number"),
# ):
#     result = num1 + num2
#     return {"num1": num1, "num2": num2, "sum": result}
#
#
# @app.post("/reports/")
# def create_report(
#     report_type: ReportType = Query(ReportType.sales, description="Type of report to generate"),
# ):
#     """Request a report. The work happens in the background."""
#     job = queue.enqueue(generate_report, report_type)
#     return {"job_id": job.id, "status": "queued", "report_type": report_type}
#
#
# @app.get("/reports/{job_id}")
# def get_report(
#     job_id: str = Path(..., description="Job ID returned by POST /reports/"),
# ):
#     """Check if a report is ready."""
#     job = Job.fetch(job_id, connection=redis_conn)
#     response = {"job_id": job_id, "status": job.get_status()}
#     if job.result is not None:
#         response["result"] = job.result
#     return response
# ```
#
# Notice the parameter annotations from section 2:
# - **`report_type`** uses `Query(...)` — comes from the query string: `/reports/?report_type=sales`
# - **`job_id`** uses `Path(...)` — comes from the URL path: `/reports/{job_id}`
# - **`ReportType`** is an `Enum` — only `sales`, `inventory`, `analytics` are accepted (anything else returns 422)
#
# ### 5.6. Connecting to Redis
#
# ```python
# redis_conn = Redis(host="redis", port=6379)
# queue = Queue(connection=redis_conn)
# ```
#
# - **`Redis(host="redis", port=6379)`** — creates a connection to the Redis server.
#   `host="redis"` works because Docker Compose resolves service names as hostnames.
#   (If running locally without Docker, you'd use `host="localhost"`)
# - **`Queue(connection=redis_conn)`** — creates an RQ queue backed by that Redis connection.
#   This is the object you call `.enqueue()` on to submit jobs.
#
# These run at **module level** (top of the file, not inside a function) so the connection is created **once** when the app starts and shared across all requests.
#
# ### 5.7. The two endpoints — why we need both
#
# We need **two** endpoints because the work is asynchronous:
#
# ```python
# # ENDPOINT 1: Submit a job (the "front door")
# @app.post("/reports/")
# def create_report(report_type: ReportType = Query(...)):
#     job = queue.enqueue(generate_report, report_type)  # put it on the queue
#     return {"job_id": job.id, "status": "queued"}       # return immediately
# ```
#
# - The caller says "I want a sales report"
# - FastAPI puts the work on the queue and **returns immediately** with a `job_id`
# - The work hasn't started yet — it's just sitting in Redis waiting for a worker
#
# ```python
# # ENDPOINT 2: Check the result (the "pickup window")
# @app.get("/reports/{job_id}")
# def get_report(job_id: str = Path(...)):
#     job = Job.fetch(job_id, connection=redis_conn)     # look up the job in Redis
#     response = {"job_id": job_id, "status": job.get_status()}
#     if job.result is not None:
#         response["result"] = job.result                # include result if done
#     return response
# ```
#
# - The caller comes back with the `job_id` and asks "is my report ready?"
# - `Job.fetch()` looks up the job in Redis by its ID
# - `job.get_status()` returns: `"queued"` / `"started"` / `"finished"` / `"failed"`
# - If the job is finished, `job.result` contains the return value of `generate_report()`
#
# **Why two endpoints?** Because the work takes 5-12 seconds. You can't hold an HTTP connection open that long. Instead:
#
# ```
# Time 0s:   POST /reports/          -> {"job_id": "abc", "status": "queued"}
# Time 1s:   GET  /reports/abc       -> {"status": "started"}
# Time 8s:   GET  /reports/abc       -> {"status": "finished", "result": {...}}
# ```
#
# This is called the **polling pattern** — submit, then check back until it's done.
#
# ### 5.8. Scaling workers
#
# Each RQ worker processes **one job at a time**. To process jobs in parallel, run multiple workers:
#
# ```bash
# # Start with 2 workers
# docker compose up --scale worker=2 -d
# ```
#
# ### 5.9. Try it — flood the queue and watch
#
# Fire off 6 reports quickly — with 2 workers, you'll see jobs queuing up:
#
# ```bash
# # Fire off 6 reports rapidly
# curl -X POST "http://localhost:8080/reports/?report_type=sales"
# curl -X POST "http://localhost:8080/reports/?report_type=inventory"
# curl -X POST "http://localhost:8080/reports/?report_type=analytics"
# curl -X POST "http://localhost:8080/reports/?report_type=sales"
# curl -X POST "http://localhost:8080/reports/?report_type=inventory"
# curl -X POST "http://localhost:8080/reports/?report_type=analytics"
# ```
#
# Now open **RQ Dashboard** at `http://localhost:9181` and watch:
# - 2 jobs will be **started** (one per worker)
# - 4 jobs will be **queued**, waiting their turn
# - As workers finish, they pick up the next job from the queue
#
# Check a specific report:
# ```bash
# curl "http://localhost:8080/reports/<job_id from above>"
# ```
#
# You'll see `"status": "queued"` -> `"started"` -> `"finished"` with the result.

# %% [markdown]
# ## 6. RQ Dashboard (Queue Monitoring)
#
# **rq-dashboard** gives you a web UI to monitor jobs in real time.
#
# - **URL:** `http://localhost:9181`
# - Shows: queued / started / finished / failed jobs
# - You can inspect individual jobs, retry failed ones, and see worker status
#
# In `docker-compose.yml` it runs as its own container:
#
# ```yaml
# rq-dashboard:
#   image: eoranged/rq-dashboard
#   ports:
#     - "9181:9181"
#   environment:
#     RQ_DASHBOARD_REDIS_URL: redis://redis:6379
#   depends_on:
#     - redis
# ```

# %% [markdown]
# ## 7. Nginx (Reverse Proxy)
#
# ### 7.1. What is Nginx?
#
# **Nginx** is a high-performance web server commonly used as a **reverse proxy** — it sits in front of your application and forwards client requests to the right backend service.
#
# ```
# [Browser] ---> [Nginx :8080] ---> [FastAPI :8000 (internal)]
# ```
#
# The browser talks to Nginx on port 8080. FastAPI's port 8000 is **internal only** — not exposed to the host.
#
# ### 7.2. Why use a reverse proxy?
#
# | Benefit | How |
# |---------|-----|
# | **Single entry point** | One public port routes to multiple internal services |
# | **TLS/SSL termination** | Nginx handles HTTPS certificates; backends stay plain HTTP |
# | **Load balancing** | Distribute requests across multiple app instances |
# | **Static file serving** | Serve CSS/JS/images without hitting your Python app |
# | **Security** | Hide internal ports, add rate limiting, security headers |
#
# ### 7.3. Our `nginx.conf` — line by line
#
# ```nginx
# events {
#     worker_connections 1024;
# }
# ```
#
# - **`events { }`** — configures how Nginx handles connections at the OS level.
# - **`worker_connections 1024`** — each Nginx worker process can handle up to 1024 simultaneous connections. This is the max number of clients that can be connected at once per worker. Default is 512; 1024 is a safe general-purpose value.
#
# ---
#
# ```nginx
# http {
#     include      /etc/nginx/mime.types;
#     sendfile     on;
# ```
#
# - **`http { }`** — the main block for all HTTP configuration. Everything related to web traffic goes here.
# - **`include /etc/nginx/mime.types`** — loads a file that maps file extensions to content types (e.g., `.html` -> `text/html`, `.json` -> `application/json`). Without this, Nginx would serve everything as `text/plain`.
# - **`sendfile on`** — uses the OS kernel to send files directly to the network socket, bypassing user-space copying. Faster for serving static files.
#
# ---
#
# ```nginx
#     upstream api {
#         server api:8000;
#     }
# ```
#
# - **`upstream api { }`** — defines a named group of backend servers called `api`.
# - **`server api:8000`** — the backend address. `api` is the Docker Compose service name, which Docker DNS resolves to the container's internal IP. Port 8000 is where Uvicorn is listening inside that container.
# - If you had multiple FastAPI instances, you'd add more `server` lines and Nginx would load-balance across them:
#   ```nginx
#   upstream api {
#       server api-1:8000;
#       server api-2:8000;
#   }
#   ```
#
# ---
#
# ```nginx
#     server {
#         listen 80;
# ```
#
# - **`server { }`** — defines a virtual server (like a site). You can have multiple `server` blocks for different domains or ports.
# - **`listen 80`** — listen on port 80 inside the container. In our `docker-compose.yml`, we map host port 8080 to container port 80 (`"8080:80"`), so the browser hits `localhost:8080` which reaches this.
#
# ---
#
# ```nginx
#         location / {
#             proxy_pass         http://api;
# ```
#
# - **`location / { }`** — matches all URL paths (everything starting with `/`). You can have multiple `location` blocks to route different paths to different backends.
# - **`proxy_pass http://api`** — forwards the request to the `upstream api` group defined above. Nginx acts as a middleman: browser -> Nginx -> FastAPI.
#
# ---
#
# ```nginx
#             proxy_http_version 1.1;
# ```
#
# - **`proxy_http_version 1.1`** — use HTTP/1.1 when talking to the backend (default is 1.0). HTTP/1.1 supports keep-alive connections, so Nginx can reuse the same connection to FastAPI for multiple requests instead of opening a new one each time.
#
# ---
#
# ```nginx
#             proxy_set_header   Host              $host;
#             proxy_set_header   X-Real-IP         $remote_addr;
#             proxy_set_header   X-Forwarded-For   $proxy_add_x_forwarded_for;
#             proxy_set_header   X-Forwarded-Proto $scheme;
# ```
#
# These pass information about the **original client** to FastAPI. Without them, FastAPI would only see Nginx's internal IP:
#
# | Header | Value | What it tells FastAPI |
# |--------|-------|----------------------|
# | `Host` | `$host` | The domain the client used (e.g., `localhost`) |
# | `X-Real-IP` | `$remote_addr` | The client's actual IP address |
# | `X-Forwarded-For` | `$proxy_add_x_forwarded_for` | Chain of IPs if there are multiple proxies |
# | `X-Forwarded-Proto` | `$scheme` | Whether the client used `http` or `https` |
#
# **Example:** A request from `192.168.1.50` hits Nginx. Without these headers, FastAPI sees the request coming from `172.18.0.3` (Nginx's Docker IP). With them, FastAPI knows the real client is `192.168.1.50`.
#
# ### 7.4. How Nginx is added to Docker Compose
#
# ```yaml
# nginx:
#   image: nginx:alpine
#   ports:
#     - "8080:80"            # host:8080 -> container:80
#   volumes:
#     - ./nginx.conf:/etc/nginx/nginx.conf:ro   # mount our config (read-only)
#   depends_on:
#     - api
# ```
#
# - **`volumes`** — mounts our `nginx.conf` file into the container, replacing the default config. `:ro` = read-only (the container can't modify our file).
# - **`depends_on`** — start the `api` container before Nginx (so there's something to proxy to).
#
# The `api` service uses `expose` (internal only) instead of `ports` (host-accessible):
# ```yaml
# api:
#   expose:
#     - "8000"       # visible to other containers, NOT to host
# ```
#
# ### 7.5. Production extras (reference)
#
# In production, Nginx also handles:
#
# - **HTTP to HTTPS redirect**:
#   ```nginx
#   location / { return 301 https://$host$request_uri; }
#   ```
#
# - **SSL certificates** (Let's Encrypt):
#   ```nginx
#   ssl_certificate     /etc/letsencrypt/live/example.com/fullchain.pem;
#   ssl_certificate_key /etc/letsencrypt/live/example.com/privkey.pem;
#   ```
#
# - **Security headers**:
#   ```nginx
#   add_header Strict-Transport-Security "max-age=31536000" always;
#   add_header X-Content-Type-Options    nosniff             always;
#   ```
#
# - **Timeouts for long requests** (e.g., ML inference):
#   ```nginx
#   proxy_read_timeout   600;
#   client_max_body_size 500M;
#   ```

# %% [markdown]
# ## 8. Docker Compose — Running Everything
#
# ### 8.1. Architecture
#
# ```
#                                  (internal Docker network)
#                               ┌──────────────────────────────┐
#                               │                              │
# [Browser :8080] ─> [Nginx] ──┼──> [FastAPI api :8000]        │
#                               │        │                     │
#                               │        │ enqueue             │
#                               │        v                     │
#                               │   [Redis :6379]              │
#                               │        │                     │
#                               │        │ dequeue             │
#                               │        v                     │
#                               │   [RQ Worker x2]             │
#                               │                              │
# [Browser :9181] ──────────────┼──> [RQ Dashboard]            │
#                               └──────────────────────────────┘
# ```
#
# Only **port 8080** (Nginx) and **port 9181** (RQ Dashboard) are exposed to the host. Everything else is internal.
#
# ### 8.2. `docker-compose.yml`
#
# ```yaml
# services:
#   nginx:
#     image: nginx:alpine
#     ports:
#       - "8080:80"
#     volumes:
#       - ./nginx.conf:/etc/nginx/nginx.conf:ro
#     depends_on:
#       - api
#     restart: unless-stopped
#
#   redis:
#     image: redis:7-alpine
#     ports:
#       - "6379:6379"
#     restart: unless-stopped
#
#   api:
#     build: .
#     expose:
#       - "8000"
#     environment:
#       LOG_LEVEL: info
#     depends_on:
#       - redis
#     restart: unless-stopped
#
#   worker:
#     build: .
#     command: rq worker --url redis://redis:6379
#     depends_on:
#       - redis
#     restart: unless-stopped
#
#   rq-dashboard:
#     image: eoranged/rq-dashboard
#     ports:
#       - "9181:9181"
#     environment:
#       RQ_DASHBOARD_REDIS_URL: redis://redis:6379
#     depends_on:
#       - redis
#     restart: unless-stopped
# ```
#
# ### 8.3. Services
#
# | Service | Image | Host port | Internal port | Role |
# |---------|-------|-----------|---------------|------|
# | `nginx` | `nginx:alpine` | **8080** | 80 | Reverse proxy — single entry point |
# | `redis` | `redis:7-alpine` | 6379 | 6379 | Message broker |
# | `api` | Built from `./dockerfile` | none | 8000 | FastAPI app |
# | `worker` | Same image as `api` | none | none | RQ worker — executes queued jobs |
# | `rq-dashboard` | `eoranged/rq-dashboard` | **9181** | 9181 | Queue monitoring UI |
#
# ### 8.4. Key concepts
#
# - **`ports`** vs **`expose`**: `ports` maps container port to host (accessible from browser). `expose` only makes the port visible to other containers.
# - **`depends_on`**: controls startup order (but doesn't wait for readiness).
# - **`volumes`**: mounts `nginx.conf` from host into the Nginx container (`:ro` = read-only).
# - **`command`**: overrides the Dockerfile `CMD` (worker uses `rq worker` instead of `uvicorn`).
# - **Service DNS**: containers reach each other by service name (`redis:6379`, `api:8000`).
# - **`--scale worker=2`**: runs 2 instances of the worker service for parallel job processing.

# %% [markdown]
# ## 9. Deploy, Update, and Operate
#
# ### 9.1. First-time setup
#
# ```bash
# cd /path/to/fastapi/
# docker compose up --build --scale worker=2 -d
# ```
#
# `--build` builds the images. `--scale worker=2` runs 2 workers. `-d` runs in the background.
#
# ### 9.2. Check status
#
# ```bash
# # See all running containers
# docker compose ps
#
# # See logs (all services)
# docker compose logs -f
#
# # See logs for one service
# docker compose logs -f api
# docker compose logs -f worker
# docker compose logs -f nginx
# ```
#
# ### 9.3. Update code and redeploy
#
# After editing `main.py`, `tasks.py`, or `requirements.txt`:
#
# ```bash
# # Rebuild only the services that changed (api + worker share the same image)
# docker compose up --build -d api worker
# ```
#
# This rebuilds the image and restarts only `api` and `worker`. Nginx and Redis stay running.
#
# ### 9.4. Update Nginx config
#
# After editing `nginx.conf`:
#
# ```bash
# # Nginx reads the config from a volume mount, so just restart it
# docker compose restart nginx
# ```
#
# No rebuild needed — the config is mounted directly from the host.
#
# ### 9.5. Restart / stop
#
# ```bash
# # Restart a single service
# docker compose restart worker
#
# # Stop and remove containers (keeps images and volumes)
# docker compose down
#
# # Stop, remove containers, AND delete Redis data
# docker compose down -v
# ```
#
# ### 9.6. Useful commands
#
# ```bash
# # Shell into a running container
# docker compose exec api bash
#
# # Run a one-off command
# docker compose run --rm api python -c "print('hello')"
#
# # See resource usage (CPU, memory)
# docker stats
#
# # Rebuild without cache (if something is stuck)
# docker compose build --no-cache
# docker compose up -d
# ```
#
# ### 9.7. Test the full stack
#
# ```bash
# # 1. Start everything with 2 workers
# docker compose up --build --scale worker=2 -d
#
# # 2. Check all services are running
# docker compose ps
#
# # 3. Test the simple endpoint (via Nginx on port 8080)
# curl "http://localhost:8080/add?num1=3&num2=7"
#
# # 4. Fire off a bunch of reports to fill the queue
# curl -X POST "http://localhost:8080/reports/?report_type=sales"
# curl -X POST "http://localhost:8080/reports/?report_type=inventory"
# curl -X POST "http://localhost:8080/reports/?report_type=analytics"
# curl -X POST "http://localhost:8080/reports/?report_type=sales"
# curl -X POST "http://localhost:8080/reports/?report_type=analytics"
# curl -X POST "http://localhost:8080/reports/?report_type=inventory"
#
# # 5. Watch the queue:  http://localhost:9181
# # 6. Check a report:
# curl "http://localhost:8080/reports/<job_id>"
#
# # 7. Swagger docs:    http://localhost:8080/docs
# ```
